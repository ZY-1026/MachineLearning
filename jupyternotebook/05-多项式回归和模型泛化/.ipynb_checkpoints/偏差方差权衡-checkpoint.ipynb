# %% [markdown]
# # 偏差和方差

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 模型误差

# %% [markdown]
# 模型误差 = 偏差（Bias）+ 方差（Variance）+ 不可避免的误差

# %% [markdown]
# # 偏差

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 方差

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 偏差和方差

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 解决高方差（过拟合）的方法：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 解决高方差的另一个方法是模型正则化
