# %% [markdown]
#  将整个数据集不划分训练和测试数据集

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 将整个数据集划分测试集和训练集

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 此时，我们可以通过观察学习曲线的走向，来判断模型是否过拟合或者欠拟合，然后进行调参

# %% [markdown]
# 有时，模型可能会在特定的测试数据集上产生过拟合

# %% [markdown]
# ![image.png](attachment:image.png)
