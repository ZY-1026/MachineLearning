# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 故定义损失函数如下

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 变形

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 对于多个样本

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 其中：![image.png](attachment:image.png)

# %% [markdown]
# # 求解损失函数的梯度

# %% [markdown]
# 损失函数：![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
